# %% [markdown]
# # Caso de Estudio COVID-19

# %%
# Librerías
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
import seaborn as sns

# para que el fonde las gráficas esté por default 
# esto en caso no hayan datos, saldrá en blanco la gráfica
sns.set()

# %% [markdown]
# ### Reombrando las columnas

# %%
def nombra_columnas(data):
    # A la izquierda va el nombre original y la derecha el 
    # el nuevo nombre o título de la columna
    # se recomienda que las variables comiencen con minúscula
    new = data.rename(
                columns = {'Province/State':'subregion',
                          'Country/Region':'país',
                          'Lat':'lat',
                          'Long':'long'})
    return new

# %% [markdown]
# ### Formato tidy

# %%
def union_date_data(data, column_name):
    
    # id_vars: mantener como en original
    # var_name: respecto a que variable se reduce el dataframe
    # value_name: el nuevo nombre que tendrá la columna
    new = data.melt(id_vars = ['país', 'subregion','lat','long'],
                   var_name = 'date_RAW',
                   value_name = column_name)
    return new

# %% [markdown]
# ### Fechas en formato datetime

# %%
def convert_date(data):
    new = data.assign(
    date = pd.to_datetime(data.date_RAW,format='%m/%d/%y'))
    new.drop(columns = ['date_RAW'],inplace = True)
    return new

# %% [markdown]
# ### Reordenar datos

# %%
def reordenar_data(data,column_name):
    new = (data.filter(
    ['país','subregion','date','lat','long',column_name])
          .sort_values(['país','subregion','date','lat','long'])
          .reset_index(drop = True))
    return new

# %% [markdown]
# ### Obtener los datos

# %%
def get_data(url,var_name):
    data_inprocess = pd.read_csv(url)
    data_inprocess = nombra_columnas(data_inprocess)
    data_inprocess = union_date_data(data_inprocess,var_name)
    data_inprocess = convert_date(data_inprocess)
    data_inprocess = reordenar_data(data_inprocess, var_name)
    
    return data_inprocess

# %%
confirmados = 'https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv'
muertos = 'https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_deaths_global.csv&filename=time_series_covid19_deaths_global.csv'
recuperados = 'https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_recovered_global.csv&filename=time_series_covid19_recovered_global.csv'


confirmados = get_data(confirmados,'confirmados')
muertos = get_data(muertos,'muertes')
recuperados = get_data(recuperados,'recuperados')

# %%
confirmados
# Out:
#                país subregion       date        lat       long  confirmados
# 0       Afghanistan       NaN 2020-01-22  33.939110  67.709953            0
# 1       Afghanistan       NaN 2020-01-23  33.939110  67.709953            0
# 2       Afghanistan       NaN 2020-01-24  33.939110  67.709953            0
# 3       Afghanistan       NaN 2020-01-25  33.939110  67.709953            0
# 4       Afghanistan       NaN 2020-01-26  33.939110  67.709953            0
# ...             ...       ...        ...        ...        ...          ...
# 290151     Zimbabwe       NaN 2022-10-17 -19.015438  29.154857       257893
# 290152     Zimbabwe       NaN 2022-10-18 -19.015438  29.154857       257893
# 290153     Zimbabwe       NaN 2022-10-19 -19.015438  29.154857       257893
# 290154     Zimbabwe       NaN 2022-10-20 -19.015438  29.154857       257893
# 290155     Zimbabwe       NaN 2022-10-21 -19.015438  29.154857       257893
#
# [290156 rows x 6 columns]

# %%
muertos
# Out:
#                país subregion       date        lat       long  muertes
# 0       Afghanistan       NaN 2020-01-22  33.939110  67.709953        0
# 1       Afghanistan       NaN 2020-01-23  33.939110  67.709953        0
# 2       Afghanistan       NaN 2020-01-24  33.939110  67.709953        0
# 3       Afghanistan       NaN 2020-01-25  33.939110  67.709953        0
# 4       Afghanistan       NaN 2020-01-26  33.939110  67.709953        0
# ...             ...       ...        ...        ...        ...      ...
# 290151     Zimbabwe       NaN 2022-10-17 -19.015438  29.154857     5606
# 290152     Zimbabwe       NaN 2022-10-18 -19.015438  29.154857     5606
# 290153     Zimbabwe       NaN 2022-10-19 -19.015438  29.154857     5606
# 290154     Zimbabwe       NaN 2022-10-20 -19.015438  29.154857     5606
# 290155     Zimbabwe       NaN 2022-10-21 -19.015438  29.154857     5606
#
# [290156 rows x 6 columns]

# %%
recuperados
# Out:
#                país subregion       date        lat       long  recuperados
# 0       Afghanistan       NaN 2020-01-22  33.939110  67.709953            0
# 1       Afghanistan       NaN 2020-01-23  33.939110  67.709953            0
# 2       Afghanistan       NaN 2020-01-24  33.939110  67.709953            0
# 3       Afghanistan       NaN 2020-01-25  33.939110  67.709953            0
# 4       Afghanistan       NaN 2020-01-26  33.939110  67.709953            0
# ...             ...       ...        ...        ...        ...          ...
# 275091     Zimbabwe       NaN 2022-10-17 -19.015438  29.154857            0
# 275092     Zimbabwe       NaN 2022-10-18 -19.015438  29.154857            0
# 275093     Zimbabwe       NaN 2022-10-19 -19.015438  29.154857            0
# 275094     Zimbabwe       NaN 2022-10-20 -19.015438  29.154857            0
# 275095     Zimbabwe       NaN 2022-10-21 -19.015438  29.154857            0
#
# [275096 rows x 6 columns]

# %%
print(len(confirmados))
print(len(muertos))
print(len(recuperados))
# Out:
# 290156
# 290156
# 275096

# %% [markdown]
# ### 3. Fusión (Merge) de los tres archivos en uno solo, eliminando columnas repetidas

# %%
muertos.drop(columns = ['lat','long'], inplace = True)
recuperados.drop(columns = ['lat','long'], inplace = True)

# %%
muertos
# Out:
#                país subregion       date  muertes
# 0       Afghanistan       NaN 2020-01-22        0
# 1       Afghanistan       NaN 2020-01-23        0
# 2       Afghanistan       NaN 2020-01-24        0
# 3       Afghanistan       NaN 2020-01-25        0
# 4       Afghanistan       NaN 2020-01-26        0
# ...             ...       ...        ...      ...
# 290151     Zimbabwe       NaN 2022-10-17     5606
# 290152     Zimbabwe       NaN 2022-10-18     5606
# 290153     Zimbabwe       NaN 2022-10-19     5606
# 290154     Zimbabwe       NaN 2022-10-20     5606
# 290155     Zimbabwe       NaN 2022-10-21     5606
#
# [290156 rows x 4 columns]

# %%
recuperados
# Out:
#                país subregion       date  recuperados
# 0       Afghanistan       NaN 2020-01-22            0
# 1       Afghanistan       NaN 2020-01-23            0
# 2       Afghanistan       NaN 2020-01-24            0
# 3       Afghanistan       NaN 2020-01-25            0
# 4       Afghanistan       NaN 2020-01-26            0
# ...             ...       ...        ...          ...
# 275091     Zimbabwe       NaN 2022-10-17            0
# 275092     Zimbabwe       NaN 2022-10-18            0
# 275093     Zimbabwe       NaN 2022-10-19            0
# 275094     Zimbabwe       NaN 2022-10-20            0
# 275095     Zimbabwe       NaN 2022-10-21            0
#
# [275096 rows x 4 columns]

# %%
# left indica que confirmados se quedará igual
# agregará Nan para los valores desconocidos cuando no hayan datos (en este caso en recuperados)
covid_19 = (confirmados
           .merge(muertos, on = ['país','subregion','date'], how = 'left')
           .merge(recuperados, on = ['país','subregion','date'], how = 'left'))

# %%
covid_19
# Out:
#                país subregion       date        lat       long  confirmados  \
# 0       Afghanistan       NaN 2020-01-22  33.939110  67.709953            0
# 1       Afghanistan       NaN 2020-01-23  33.939110  67.709953            0
# 2       Afghanistan       NaN 2020-01-24  33.939110  67.709953            0
# 3       Afghanistan       NaN 2020-01-25  33.939110  67.709953            0
# 4       Afghanistan       NaN 2020-01-26  33.939110  67.709953            0
# ...             ...       ...        ...        ...        ...          ...
# 290151     Zimbabwe       NaN 2022-10-17 -19.015438  29.154857       257893
# 290152     Zimbabwe       NaN 2022-10-18 -19.015438  29.154857       257893
# 290153     Zimbabwe       NaN 2022-10-19 -19.015438  29.154857       257893
# 290154     Zimbabwe       NaN 2022-10-20 -19.015438  29.154857       257893
# 290155     Zimbabwe       NaN 2022-10-21 -19.015438  29.154857       257893
#
#         muertes  recuperados
# 0             0          0.0
# 1             0          0.0
# 2             0          0.0
# 3             0          0.0
# 4             0          0.0
# ...         ...          ...
# 290151     5606          0.0
# 290152     5606          0.0
# 290153     5606          0.0
# 290154     5606          0.0
# 290155     5606          0.0
#
# [290156 rows x 8 columns]

# %%
len(covid_19)
# Out:
# 290156

# %% [markdown]
# ### 4. Realización de un Análisis Exploratorio de Datos.

# %%
covid_19.head()
# Out:
#           país subregion       date       lat       long  confirmados  \
# 0  Afghanistan       NaN 2020-01-22  33.93911  67.709953            0
# 1  Afghanistan       NaN 2020-01-23  33.93911  67.709953            0
# 2  Afghanistan       NaN 2020-01-24  33.93911  67.709953            0
# 3  Afghanistan       NaN 2020-01-25  33.93911  67.709953            0
# 4  Afghanistan       NaN 2020-01-26  33.93911  67.709953            0
#
#    muertes  recuperados
# 0        0          0.0
# 1        0          0.0
# 2        0          0.0
# 3        0          0.0
# 4        0          0.0

# %% [markdown]
# **Datos faltantes**

# %%
pd.set_option('display.max_rows', 180)
(covid_19
.filter(['país'])
.drop_duplicates())
# Out:
#                         país
# 0                Afghanistan
# 1004                 Albania
# 2008                 Algeria
# 3012                 Andorra
# 4016                  Angola
# ...                      ...
# 285136    West Bank and Gaza
# 286140  Winter Olympics 2022
# 287144                 Yemen
# 288148                Zambia
# 289152              Zimbabwe
#
# [201 rows x 1 columns]

# %% [markdown]
#  **Validando los datos**

# %%
covid_19.filter(['long','lat']).agg(['min','max'])
# Out:
#          long      lat
# min -178.1165 -71.9499
# max  178.0650  71.7069

# %%
covid_19.filter(['confirmados','muertes','recuperados']).describe()
# Out:
#         confirmados       muertes   recuperados
# count  2.901560e+05  2.901560e+05  2.740920e+05
# mean   7.776613e+05  1.201078e+04  8.474238e+04
# std    4.158791e+06  5.887012e+04  7.512953e+05
# min    0.000000e+00  0.000000e+00 -1.000000e+00
# 25%    4.320000e+02  2.000000e+00  0.000000e+00
# 50%    1.033950e+04  1.150000e+02  0.000000e+00
# 75%    1.752648e+05  2.495250e+03  1.599000e+03
# max    9.718556e+07  1.067673e+06  3.097475e+07

# %%
covid_19.query('confirmados < 0 or muertes < 0 or recuperados < 0 ')
# Out:
#                   país         subregion       date      lat      long  \
# 277065  United Kingdom  Pitcairn Islands 2022-09-13 -24.3768 -128.3242
# 277066  United Kingdom  Pitcairn Islands 2022-09-14 -24.3768 -128.3242
# 277067  United Kingdom  Pitcairn Islands 2022-09-15 -24.3768 -128.3242
# 277068  United Kingdom  Pitcairn Islands 2022-09-16 -24.3768 -128.3242
# 277069  United Kingdom  Pitcairn Islands 2022-09-17 -24.3768 -128.3242
# 277070  United Kingdom  Pitcairn Islands 2022-09-18 -24.3768 -128.3242
# 277071  United Kingdom  Pitcairn Islands 2022-09-19 -24.3768 -128.3242
# 277072  United Kingdom  Pitcairn Islands 2022-09-20 -24.3768 -128.3242
#
#         confirmados  muertes  recuperados
# 277065            4        0         -1.0
# 277066            4        0         -1.0
# 277067            4        0         -1.0
# 277068            4        0         -1.0
# 277069            4        0         -1.0
# 277070            4        0         -1.0
# 277071            4        0         -1.0
# 277072            4        0         -1.0

# %%
covid_19 = covid_19.query("not(confirmados < 0 or muertes < 0 or recuperados < 0 )")

# %%
print(len(covid_19))
# Out:
# 290148

# %%
covid_19.filter(['confirmados','muertes','recuperados']).describe()
# Out:
#         confirmados       muertes   recuperados
# count  2.901480e+05  2.901480e+05  2.740840e+05
# mean   7.776827e+05  1.201111e+04  8.474485e+04
# std    4.158846e+06  5.887089e+04  7.513061e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.320000e+02  2.000000e+00  0.000000e+00
# 50%    1.034300e+04  1.150000e+02  0.000000e+00
# 75%    1.752700e+05  2.496000e+03  1.599000e+03
# max    9.718556e+07  1.067673e+06  3.097475e+07

# %%
covid_19.isnull().sum()
# Out:
# país                0
# subregion      198792
# date                0
# lat              2008
# long             2008
# confirmados         0
# muertes             0
# recuperados     16064
# dtype: int64

# %%
covid_19 = covid_19.fillna(value = {'subregion':'','lat':np.NaN,'long':np.NaN,'recuperados':0})

# %%
casos_nuevos = (covid_19
               .sort_values(by = ['país','subregion','date'])
               .filter(['país','subregion','date','confirmados'])
               .groupby(['país','subregion'])
               .diff())

# %%
casos_nuevos
# Out:
#          date  confirmados
# 0         NaT          NaN
# 1      1 days          0.0
# 2      1 days          0.0
# 3      1 days          0.0
# 4      1 days          0.0
# ...       ...          ...
# 290151 1 days          0.0
# 290152 1 days          0.0
# 290153 1 days          0.0
# 290154 1 days          0.0
# 290155 1 days          0.0
#
# [290148 rows x 2 columns]

# %%
covid_19 = covid_19.assign(casos_nuevos = 'casos_nuevos')

# %%
covid_19
# Out:
#                país subregion       date        lat       long  confirmados  \
# 0       Afghanistan           2020-01-22  33.939110  67.709953            0
# 1       Afghanistan           2020-01-23  33.939110  67.709953            0
# 2       Afghanistan           2020-01-24  33.939110  67.709953            0
# 3       Afghanistan           2020-01-25  33.939110  67.709953            0
# 4       Afghanistan           2020-01-26  33.939110  67.709953            0
# ...             ...       ...        ...        ...        ...          ...
# 290151     Zimbabwe           2022-10-17 -19.015438  29.154857       257893
# 290152     Zimbabwe           2022-10-18 -19.015438  29.154857       257893
# 290153     Zimbabwe           2022-10-19 -19.015438  29.154857       257893
# 290154     Zimbabwe           2022-10-20 -19.015438  29.154857       257893
# 290155     Zimbabwe           2022-10-21 -19.015438  29.154857       257893
#
#         muertes  recuperados  casos_nuevos
# 0             0          0.0  casos_nuevos
# 1             0          0.0  casos_nuevos
# 2             0          0.0  casos_nuevos
# 3             0          0.0  casos_nuevos
# 4             0          0.0  casos_nuevos
# ...         ...          ...           ...
# 290151     5606          0.0  casos_nuevos
# 290152     5606          0.0  casos_nuevos
# 290153     5606          0.0  casos_nuevos
# 290154     5606          0.0  casos_nuevos
# 290155     5606          0.0  casos_nuevos
#
# [290148 rows x 9 columns]

# %%
covid_19['infectados'] = covid_19['confirmados'] - covid_19['muertes']-covid_19['recuperados']

# %%
covid_19
# Out:
#                país subregion       date        lat       long  confirmados  \
# 0       Afghanistan           2020-01-22  33.939110  67.709953            0
# 1       Afghanistan           2020-01-23  33.939110  67.709953            0
# 2       Afghanistan           2020-01-24  33.939110  67.709953            0
# 3       Afghanistan           2020-01-25  33.939110  67.709953            0
# 4       Afghanistan           2020-01-26  33.939110  67.709953            0
# ...             ...       ...        ...        ...        ...          ...
# 290151     Zimbabwe           2022-10-17 -19.015438  29.154857       257893
# 290152     Zimbabwe           2022-10-18 -19.015438  29.154857       257893
# 290153     Zimbabwe           2022-10-19 -19.015438  29.154857       257893
# 290154     Zimbabwe           2022-10-20 -19.015438  29.154857       257893
# 290155     Zimbabwe           2022-10-21 -19.015438  29.154857       257893
#
#         muertes  recuperados  casos_nuevos  infectados
# 0             0          0.0  casos_nuevos         0.0
# 1             0          0.0  casos_nuevos         0.0
# 2             0          0.0  casos_nuevos         0.0
# 3             0          0.0  casos_nuevos         0.0
# 4             0          0.0  casos_nuevos         0.0
# ...         ...          ...           ...         ...
# 290151     5606          0.0  casos_nuevos    252287.0
# 290152     5606          0.0  casos_nuevos    252287.0
# 290153     5606          0.0  casos_nuevos    252287.0
# 290154     5606          0.0  casos_nuevos    252287.0
# 290155     5606          0.0  casos_nuevos    252287.0
#
# [290148 rows x 10 columns]

# %% [markdown]
# ### 5. Generación de nueva información calculando nuevas columnas como:
